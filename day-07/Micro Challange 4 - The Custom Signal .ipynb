# %% [markdown]
# # Goal: Ask the user for a number.if the number is negative,manually trigger an error using raise valueError("No Negatuve")

# %%
try:
    val = int(input("Enter the value"))
    if val<0:
        raise ValueError("No Negative")
    print("It is a positive number")

except ValueError as e:
    print(f"Error:{e}")
# Out:
# Enter the value -5
# Error:No Negative
