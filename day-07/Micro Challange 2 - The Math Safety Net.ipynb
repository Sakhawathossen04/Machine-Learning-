# %% [markdown]
# # Goal: Create a variable x= 0 .Try to print 100/x . Catch the specrific error that occurs.

# %%
x = 0 
try : 
    print(100/0)
except ZeroDivisionError:
    print("The value of X is 0 .That infinity")
# Out:
# The value of X is 0 .That infinity

# %% [markdown]
# # The Mechanics : Division by zero is mathematically undifeined .At the CPU level ,the ALU Throws a hardware interrupt . python wraps this intro a ZerDivisiionError obhect.Catching this allows your data pipeline to say skipping bad row instead of halting a 10 h process.
