# %% [markdown]
# # Goal: Write a script that asks the user for their age.if they type text eg(twenty not 20) print numbers only insted of crashing.

# %% [markdown]
# Constraint: Use try/except ValueError

# %%
try :
    val = int(input("Enter the age: "))
    print(f"The age is : {val}")

except ValueError:
    print("Enter the int format")
# Out:
# Enter the age:  aeew
# Enter the int format
