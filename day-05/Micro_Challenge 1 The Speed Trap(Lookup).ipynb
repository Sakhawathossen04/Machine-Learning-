# %% [markdown]
# # Goal : Create a list of 1 million numbers . Create a set of the same numbers.check if the number -1 exists in both

# %% [markdown]
# # List search O(n) : python must scan item 1,2,3,4, until the end.
# # Dict /set search O(1) : python run hash(-1),gets a memery address .and look only at that sopt . it is inatant

# %%
# 10 lakh numbers er data
my_list = [0, 1, 2, 3, 4, ..., 999999] 
my_set  = {0, 1, 2, 3, 4, ..., 999999}


"-1" in my_list  # Python ektar por ekta 10 lakh bar check korbe (Dhire)
"-1" in my_set   # Python thik thikana (address) jane, ekbar-e bole dibe (Fast)
# Out:
# False
