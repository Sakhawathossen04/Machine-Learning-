# %%
# Default settings
defaults ={"theme":"light","audio":"on"}

user_pref = {"theme" : "dark" ,"audio":"off"}

merge = defaults | user_pref   # update 
merge
# Out:
# {'theme': 'dark', 'audio': 'off'}
