# %% [markdown]
# # Goal:Input a string "banana" .Create a dictionary that counts the freq of each letter

# %%
word = "banna"
freq ={}

for char in word:
    if char in freq:
        freq[char]+=1
    else:
        freq[char] = 1
print (freq)
# Out:
# {'b': 1, 'a': 2, 'n': 2}
