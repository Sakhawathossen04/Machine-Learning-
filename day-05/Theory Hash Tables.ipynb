# %% [markdown]
# # Dictionaries(Hash Maps)

# %% [markdown]
# # A dictionary is a key - value sotre . its optimized for O(1) .
# # when you search a list ,python scans left to right . O(N) . When you searh a dictionary ,python uses a hash function.to calsi where the data is in memeory.It is instant ,even with 1 million items
