# %% [markdown]
# # The physics of code (Time Complexity)

# %% [markdown]
# # Goal : Create a list of 10 million numbers . Check if -5 is in the list .Deep Dive : Python performs a Linear Seacrh .  is loads index 0,compares,loads index 1 ,compares... all the way to 10 million . Complesity: O(N) .If data doubles , time doubles.

# %%
# Task:Check if a value exists in a list

# %% [markdown]
# # Pseudo code logic

# %% [markdown]
# Function contains(list,target):
#     index = 0
#     length = list.size
#
#     WHILE index < length:
#         current_value = list[index]
#             offset
#         IF current_value == target:
#             Return True
#         index = index + 1
#     RETURN False
#         match

# %% [markdown]
# In a list , data is stored sequentially in memory . to find a specific value , the CPU must check the first address, then second,then the third. There is no shortcut . if the list has 1 million items, the Worst Cse scenario requires 1 million comparison operation . This linear relationship is O(N)

# %%
def contain(list,target):
    index = 0
    length = len(list)
    
    while index<length:
        current_value = list[index]
            
        if current_value == target:
            return True
        index=index +1 

    return False

# %%
target = 5
list= [1,2,5,4,6,7,9]

# %%
contain(list,target)
# Out:
# True
