# %% [markdown]
# # Goal: Crate a string word  = "DATA" .Write a loop that prints every letter on a new line

# %%
word = "DATA"

for i in range(0,len(word)):
    print(word[i])
# Out:
# D
# A
# T
# A
