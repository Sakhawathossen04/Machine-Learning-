# %% [markdown]
# # Loop through dictionary

# %%
car = {"brand":"BMW" , "Model":"M4","year":2018}

# %%
car.items()
# Out:
# dict_items([('brand', 'BMW'), ('Model', 'M4'), ('year', 2018)])

# %%
for key,value in car.items():
    print(key, ":",value)
# Out:
# brand : BMW
# Model : M4
# year : 2018
