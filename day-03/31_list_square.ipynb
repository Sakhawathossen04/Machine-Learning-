# %% [markdown]
# # Square elements of list

# %%
num = [1,2,3,4,5]
for i in num:
    print(i*i)
    i=i+1
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
num = [1,2,3,4,5]
sqr_num = []

for i in num:
    sqr_num.append(i*i)
    i=i+1

# %%
sqr_num
# Out:
# [1, 4, 9, 16, 25]
