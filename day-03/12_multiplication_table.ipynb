# %% [markdown]
# # Multiplicant Table

# %%
n = 3

for i in range(1,10):
    print(n , "*",i,"=" ,n*1)
# Out:
# 3 * 1 = 3
# 3 * 2 = 3
# 3 * 3 = 3
# 3 * 4 = 3
# 3 * 5 = 3
# 3 * 6 = 3
# 3 * 7 = 3
# 3 * 8 = 3
# 3 * 9 = 3
