# %% [markdown]
# # Goal : Write a script that asks the user for a password repeatedly .it must run forever until the user type "stop "

# %%
# here we use while true for create a infinit cycle .

# %%
while True:
    passw = input("Enter the password")

    if passw == "stop":
        print("The loop is end")
        break;
    print("Type the another pass")
