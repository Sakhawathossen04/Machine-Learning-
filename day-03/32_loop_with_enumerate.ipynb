# %% [markdown]
# # enumerate হলো Python-এর একটা বিল্ট-ইন ফাংশন। এটা লিস্টের প্রতিটি আইটেমের সাথে তার index (অবস্থান) জোড়া করে দেয়।

# %%
names = ["a","b","c"]
for i , name in enumerate(names):
    print(i,name)
# Out:
# 0 a
# 1 b
# 2 c
