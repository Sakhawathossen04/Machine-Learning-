# %%
# Goal : Ask the user for a number N (eg:5) .Calsi the sum of all numbers to N .

# %%
n = int(input("Enter the val:"))
sum = 0
i = 1
while i<=n:
    sum+=i
    i+=1
print(f"The sum is : {sum}")
# Out:
# Enter the val: 5
# The sum is : 15

# %%
# if we do this using mathmetical operation that like this:

N = int(input("Enter the val:"))

s = (n*n +1 )/2
s
# Out:
# Enter the val: 5
# 13.0
