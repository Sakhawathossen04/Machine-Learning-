# %% [markdown]
# # Goal : You have a var score = 85 ,Assign a var status to "Pass" is score >70 else "Fail" . Condition is do this in exactly one line of code

# %%
score = 70

# %%
status = "Pass " if score>70 else "Fail"

# %%
status
# Out:
# 'Fail'
