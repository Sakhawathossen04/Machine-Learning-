# %% [markdown]
# # Goal: Create a variable data = [] (empty list) . Write an is statement to print "Data Found " or "No Found" Without comparing it to anyting ex:(do not use len(data)>0 ).

# %%
mylist = []
