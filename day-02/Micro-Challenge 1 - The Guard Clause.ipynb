# %% [markdown]
# # Goal: Create a vaiable user = None . Write an if statement that checks if user is not None And is user has "admin" access

# %%
user = None

if user is not None and user == "admin" :
    print("Access granted")

else: 
    print("Not Access")
# Out:
# Not Access

# %%
# note : Here we use And operator . that means both side need to be True.
