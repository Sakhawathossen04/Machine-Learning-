# %% [markdown]
# # Goal :  Write a script that checks if 0.1 + 0.3 == 0.3 . print the result (T/F).

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
# there we not get 0.3 .we find e 16 bit floating number . its cause error, dont fullfill the contional operation ,so we need to round the sum
# in this problem when we sum 2 value then the reuslt store in floating number and containing 16 bit addreses.also show 16 bit . if we wanna solve this problem we must need to be round the value .
# like a + b = c:0.2

# %%
a = 0.1 
b=0.2
c=a+b

# %%
c
# Out:
# 0.30000000000000004

# %%
round(a+b,2)
# Out:
# 0.3

# %%
round(c,2)
# Out:
# 0.3

# %%
if round(a+b,2) == round(c,2) :
    print(True)

else:
    print(False)
# Out:
# True
