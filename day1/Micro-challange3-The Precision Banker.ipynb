# %% [markdown]
# # Goal:Create a variable bill  = 10/3.Print the result formatted strictly to 3 decimal places with a dollar sign (ex:$3.333)

# %%
bill = 100/3
print(f"the bill is : {bill}")
# Out:
# the bill is : 33.333333333333336

# %% [markdown]
# Python floats use IEEE 754 double precision (64 bit) . The actual number in memory is 33.33333333336.F-STRING act as a "view Layer," masking the raw precision for the user without altering the underlying data integrity.

# %%
print(f"the bill is :{bill:0.5}")
# Out:
# the bill is :33.333
