# %%
# standard Input

val = input("enter the value: ")
# Out:
# enter the value:  5

# %%
val
# Out:
# '5'

# %%
# convert the dtype

# %%
float(val)
# Out:
# 5.0

# %% [markdown]
# # Standard way to follow convert the dtype  / Casting

# %%
try : 
    float_val = float(val)
    print(f"the floated_val is : {float_val}")

except ValueError:
    print("Error: Invalid Number")
# Out:
# the floated_val is : 5.0
