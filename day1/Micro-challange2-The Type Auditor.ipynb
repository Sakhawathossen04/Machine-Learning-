# %% [markdown]
# # Goal:Ask the user to type a number .
#     1.Input the data from user
#     2.print the type of data
#     3.cast to float
#     4.print again the type

# %%
val1 = input("enter the value")
type(val1)
# Out:
# enter the value 5
# str

# %%
try :
    val2 = float(val1)
    val3 = int(val1)
    print(f"The val2 datatype is: {type(val2)}")
    print(f"The val3 datatype is: {type(val3)}")

except ValueError:
    print("Invalid")
# Out:
# The val2 datatype is: <class 'float'>
# The val3 datatype is: <class 'int'>
