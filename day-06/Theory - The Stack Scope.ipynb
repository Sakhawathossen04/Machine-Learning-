# %% [markdown]
# # When a function is called ,python create a stack frame in memory .all variable created inside the functuion live here.When the function returns ,the frame is distroyed.

# %% [markdown]
# # Python searches for var in this order: local --> Enclosing --> Global --> build-in

# %%
def calsi_area(r):
    if r<0:
        return 0
    return 3.1416*r*r

radius = 5
calsi_area(radius)
# Out:
# 78.54
