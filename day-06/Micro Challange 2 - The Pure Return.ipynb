# %% [markdown]
# # Goal : Write a function  add(a,b) that prints thesum but resutns nothing.Assign the result to a variable res = add(5,5) .print res

# %%
def add(a,b):
    return a+b

res = add(5,5)
res
# Out:
# 10
