# %% [markdown]
# # Goal : Create a global Variable x = 10 . write a function change_() that sets x = 20 inside it.print x outside the function

# %%
x = 10
def change_():
    x=20

print(x)
# Out:
# 10

# %% [markdown]
# # Note : It print 10, Noy 20 Bcz, x = 10 is global variable ,which access bothside the funciton  and x = 20 is assign inside the function so it cannt print 20
