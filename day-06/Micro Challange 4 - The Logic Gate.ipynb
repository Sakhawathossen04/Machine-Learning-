# %% [markdown]
# # Goal : Write a funstion is_even(num) that returns True if even ,False otherwise. Do not use if/else . do it in one line

# %%
def is_even(num):
    return num%2==0

is_even(4)
# Out:
# True
