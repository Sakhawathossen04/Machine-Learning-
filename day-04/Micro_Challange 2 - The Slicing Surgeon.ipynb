# %% [markdown]
# # Goal: Create a list data =[10,20,30,40,50] .Create a new list containing the last 3 items in revers order.

# %%
data =[10,20,30,40,50,60]

b=data[-1:-4:-1]

# %%
b
# Out:
# [60, 50, 40]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60]
