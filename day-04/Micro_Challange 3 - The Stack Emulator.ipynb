# %% [markdown]
# # Goal: Create an empty list . Add numbers 1,2,3 .Then remove the last number 3 and print

# %%
data =[1,2,3]
data.pop(2)
# Out:
# 3

# %%
val=[]
val.append(1)
val.append(2)
val.append(3)
val
# Out:
# [1, 2, 3]

# %%
val.pop(2)
# Out:
# 3
