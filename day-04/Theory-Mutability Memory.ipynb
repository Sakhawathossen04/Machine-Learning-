# %% [markdown]
# # Lists are Mutable . This means they can be changed in place .
# # The aliasing Trap: A =[1,2] B=A this is does not copy the list . it creates a second name for the same list. modify B will destroy A . Solution : Always use B = A.copy

# %%
A = [10,20,30,40,20]
B = A.copy()

# %%
B
# Out:
# [10, 20, 30, 40, 20]
