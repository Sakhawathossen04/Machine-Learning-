# %% [markdown]
# Goal : Write a function add(x,y) using lambda . Deep Dive : lambda creates a function pnject on the heap but assigns it no name (unless you bind it to a variable).it is purely syntatic sugat for single expression function.

# %% [markdown]
# # Task lambda x: x+1

# %%
def add(a,b):
    return a+b

add(4,5)
# Out:
# 9

# %%
add = lambda a,b: a + b 
print(add(3,4))
# Out:
# 7

# %%
print((lambda x:x*x)(5))
# Out:
# 25
