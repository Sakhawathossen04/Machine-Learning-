# %% [markdown]
# # Goal : Combine names = ["A","B"] and ages =[20,30] intro dictionary
# # Deep Dive : dict(zip(names,ages)).zip   creates an iterator of tuples . dict() consumes those tuples to nuild the hash map.

# %% [markdown]
# # Example 1

# %%
print(dict(zip(['A','B'],[20,30])))
# Out:
# {'A': 20, 'B': 30}

# %% [markdown]
# # Example 2

# %%
print(list(zip([1,2,3],['a','b'])))
# Out:
# [(1, 'a'), (2, 'b')]
