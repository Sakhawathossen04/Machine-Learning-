# %% [markdown]
# ![image.png](attachment:94c54f79-01be-461b-ab21-8cf2b720c88b.png)

# %%
import numpy as np

# Shape: (5, 2)
data_points = np.array([
    [1, 1],
    [2, 1],
    [2, 2],
    [1, 2],
    [1.5, 1.5]
], dtype=float)

shear_matrix = np.array([
    [1, 1.5],
    [0, 1]
], dtype=float)

# Apply shear to all points (vectorized)
transformed_points = (shear_matrix @ data_points.T).T

print("--- Problem 2 Results ---")
print(f"Original Points:\n{data_points}\n")
print(f"Sheared Points:\n{transformed_points}\n")
# Out:
# --- Problem 2 Results ---
# Original Points:
# [[1.  1. ]
#  [2.  1. ]
#  [2.  2. ]
#  [1.  2. ]
#  [1.5 1.5]]
#
# Sheared Points:
# [[2.5  1.  ]
#  [3.5  1.  ]
#  [5.   2.  ]
#  [4.   2.  ]
#  [3.75 1.5 ]]
